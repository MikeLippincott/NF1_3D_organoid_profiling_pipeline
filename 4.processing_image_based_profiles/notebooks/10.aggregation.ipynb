# %% [markdown]
# This notebook performs profile aggregation.

# %%
import argparse
import os
import pathlib
import sys

import pandas as pd
from arg_parsing_utils import parse_args
from notebook_init_utils import bandicoot_check, init_notebook
from pycytominer import aggregate

root_dir, in_notebook = init_notebook()

profile_base_dir = bandicoot_check(
    pathlib.Path(os.path.expanduser("~/mnt/bandicoot/NF1_organoid_data")).resolve(),
    root_dir,
)

# %%
if not in_notebook:
    args = parse_args()
    patient = args["patient"]
    image_based_profiles_subparent_name = args["image_based_profiles_subparent_name"]

else:
    patient = "NF0014_T1"
    image_based_profiles_subparent_name = "image_based_profiles"

# %%
# pathing
sc_fs_path = pathlib.Path(
    f"{profile_base_dir}/data/{patient}/{image_based_profiles_subparent_name}/5.feature_selected_profiles/sc_fs.parquet"
).resolve(strict=True)
organoid_fs_path = pathlib.Path(
    f"{profile_base_dir}/data/{patient}/{image_based_profiles_subparent_name}/5.feature_selected_profiles/organoid_fs.parquet"
).resolve(strict=True)


# output path
sc_agg_well_output_path = pathlib.Path(
    f"{profile_base_dir}/data/{patient}/{image_based_profiles_subparent_name}/6.aggregated_profiles/sc_agg_well_level.parquet"
).resolve()
sc_agg_well_parent_organoid_output_path = pathlib.Path(
    f"{profile_base_dir}/data/{patient}/{image_based_profiles_subparent_name}/6.aggregated_profiles/sc_agg_parent_organoid_level.parquet"
).resolve()
sc_consensus_output_path = pathlib.Path(
    f"{profile_base_dir}/data/{patient}/{image_based_profiles_subparent_name}/6.aggregated_profiles/sc_consensus.parquet"
).resolve()

organoid_agg_well_output_path = pathlib.Path(
    f"{profile_base_dir}/data/{patient}/{image_based_profiles_subparent_name}/6.aggregated_profiles/organoid_agg_well_level.parquet"
).resolve()
organoid_consensus_output_path = pathlib.Path(
    f"{profile_base_dir}/data/{patient}/{image_based_profiles_subparent_name}/6.aggregated_profiles/organoid_consensus.parquet"
).resolve()

organoid_consensus_output_path.parent.mkdir(parents=True, exist_ok=True)

# %%
# read in the data
sc_fs = pd.read_parquet(sc_fs_path)
organoid_fs = pd.read_parquet(organoid_fs_path)

# %% [markdown]
# ### Aggregate the single cell profiles
# We will aggregated with a few different stratifications:
# 1. Well
# 2. Well and parent organoid
# 3. Treatment - i.e. the consensus profile for each treatment

# %%
sc_fs.head()
# Out:
#   Metadata_patient_tumor  Metadata_object_id Metadata_unit  Metadata_dose  \
# 0              NF0014_T1                  61            uM              1
# 1              NF0014_T1                 114            uM              1
# 2              NF0014_T1                 184            uM              1
# 3              NF0014_T1                 219            uM              1
# 4              NF0014_T1                 255            uM              1
#
#   Metadata_treatment Metadata_image_set Metadata_Well  \
# 0       Fimepinostat               E5-2            E5
# 1       Fimepinostat               E5-2            E5
# 2       Fimepinostat               E5-2            E5
# 3       Fimepinostat               E5-2            E5
# 4       Fimepinostat               E5-2            E5
#
#    Metadata_parent_organoid          Metadata_Target  Metadata_Class  ...  \
# 0                        -1  PI3K and HDAC inhibitor  Small Molecule  ...
# 1                        -1  PI3K and HDAC inhibitor  Small Molecule  ...
# 2                        -1  PI3K and HDAC inhibitor  Small Molecule  ...
# 3                        -1  PI3K and HDAC inhibitor  Small Molecule  ...
# 4                        -1  PI3K and HDAC inhibitor  Small Molecule  ...
#
#   Texture_Cytoplasm_Mito_Difference.Entropy_256.3  \
# 0                                       -0.853288
# 1                                        0.234114
# 2                                       -0.292831
# 3                                       -0.292831
# 4                                       -0.341044
#
#   Texture_Cytoplasm_Mito_Difference.Variance_256.3  \
# 0                                         0.666296
# 1                                        -0.146387
# 2                                         0.265720
# 3                                         0.265720
# 4                                         0.297917
#
#   Texture_Cytoplasm_Mito_Entropy_256.3  \
# 0                            -0.744992
# 1                             0.204914
# 2                            -0.284591
# 3                            -0.284591
# 4                            -0.323744
#
#    Texture_Cytoplasm_Mito_Information.Measure.of.Correlation.1_256.3  \
# 0                                          -1.727884
# 1                                          -0.566253
# 2                                          -0.337570
# 3                                          -0.337570
# 4                                          -0.281410
#
#    Texture_Cytoplasm_Mito_Information.Measure.of.Correlation.2_256.3  \
# 0                                          -0.795478
# 1                                           0.507400
# 2                                          -0.143982
# 3                                          -0.143982
# 4                                          -0.210875
#
#    Texture_Cytoplasm_Mito_Inverse.Difference.Moment_256.3  \
# 0                                           0.744107
# 1                                          -0.180214
# 2                                           0.291757
# 3                                           0.291757
# 4                                           0.324488
#
#    Texture_Cytoplasm_Mito_Sum.Average_256.3  \
# 0                                 -0.887714
# 1                                  0.699770
# 2                                 -0.415339
# 3                                 -0.415339
# 4                                 -0.010976
#
#    Texture_Cytoplasm_Mito_Sum.Entropy_256.3  \
# 0                                 -0.778888
# 1                                  0.221479
# 2                                 -0.290942
# 3                                 -0.290942
# 4                                 -0.334375
#
#    Texture_Cytoplasm_Mito_Sum.Variance_256.3  \
# 0                                  -0.756731
# 1                                   1.005875
# 2                                  -0.489394
# 3                                  -0.489394
# 4                                   0.466926
#
#    Texture_Cytoplasm_Mito_Variance_256.3
# 0                              -0.807663
# 1                               1.009380
# 2                              -0.508018
# 3                              -0.508018
# 4                               0.503383
#
# [5 rows x 5889 columns]

# %%
sc_metadata_columns = [x for x in sc_fs.columns if "Metadata" in x]

sc_metadata_columns += [
    "Area.Size.Shape_Cell_CENTER.X",
    "Area.Size.Shape_Cell_CENTER.Y",
    "Area.Size.Shape_Cell_CENTER.Z",
]
sc_features_columns = [col for col in sc_fs.columns if col not in sc_metadata_columns]
sc_features_df = sc_fs.drop(columns=sc_metadata_columns, errors="ignore")

# %%
# stratification approach #1
sc_well_agg = aggregate(
    population_df=sc_fs,
    strata=[
        "Metadata_Well",
        "Metadata_treatment",
        "Metadata_Target",
        "Metadata_Class",
        "Metadata_Therapeutic_Categories",
    ],
    features=sc_features_columns,
    operation="median",
)
sc_well_agg.to_parquet(sc_agg_well_output_path, index=False)

# stratification approach #2
sc_well_parent_organoid_agg = aggregate(
    population_df=sc_fs,
    strata=[
        "Metadata_Well",
        "Metadata_parent_organoid",
        "Metadata_treatment",
        "Metadata_Target",
        "Metadata_Class",
        "Metadata_Therapeutic_Categories",
    ],
    features=sc_features_columns,
    operation="median",
)
sc_well_parent_organoid_agg.to_parquet(
    sc_agg_well_parent_organoid_output_path, index=False
)
# stratification approach #3
sc_consensus = aggregate(  # a.k.a. consensus
    population_df=sc_fs,
    strata=[
        "Metadata_treatment",
        "Metadata_Target",
        "Metadata_Class",
        "Metadata_Therapeutic_Categories",
    ],
    features=sc_features_columns,
    operation="median",
)
sc_consensus.to_parquet(sc_consensus_output_path, index=False)

# %% [markdown]
# ### Aggregate the organoid profiles
# We will aggregated with a few different stratifications:
# 1. Well
# 2. Treatment - i.e. the consensus profile for each treatment

# %%
organoid_fs.head()
# Out:
#   Metadata_patient_tumor  Metadata_object_id Metadata_unit  Metadata_dose  \
# 0              NF0014_T1                   2            uM              1
# 1              NF0014_T1                   4            uM              1
# 2              NF0014_T1                   7            uM              1
# 3              NF0014_T1                  19            uM              1
# 4              NF0014_T1                  23            uM              1
#
#   Metadata_treatment Metadata_image_set Metadata_Well  \
# 0       Fimepinostat               E5-2            E5
# 1       Fimepinostat               E5-2            E5
# 2       Fimepinostat               E5-2            E5
# 3       Fimepinostat               E5-2            E5
# 4       Fimepinostat               E5-2            E5
#
#    Metadata_single_cell_count          Metadata_Target  Metadata_Class  ...  \
# 0                         NaN  PI3K and HDAC inhibitor  Small Molecule  ...
# 1                         NaN  PI3K and HDAC inhibitor  Small Molecule  ...
# 2                         NaN  PI3K and HDAC inhibitor  Small Molecule  ...
# 3                         NaN  PI3K and HDAC inhibitor  Small Molecule  ...
# 4                         NaN  PI3K and HDAC inhibitor  Small Molecule  ...
#
#   Texture_Organoid_Mito_Difference.Entropy_256.3  \
# 0                                      -0.799700
# 1                                      -0.790156
# 2                                      -0.799328
# 3                                      -0.797577
# 4                                       0.990027
#
#   Texture_Organoid_Mito_Difference.Variance_256.3  \
# 0                                        0.727493
# 1                                        0.722770
# 2                                        0.727338
# 3                                        0.726521
# 4                                       -0.917486
#
#   Texture_Organoid_Mito_Entropy_256.3  \
# 0                           -0.707564
# 1                           -0.701173
# 2                           -0.707337
# 3                           -0.706253
# 4                            0.847170
#
#    Texture_Organoid_Mito_Information.Measure.of.Correlation.1_256.3  \
# 0                                           1.408761
# 1                                          -0.081791
# 2                                           1.408760
# 3                                           1.309233
# 4                                          -1.158874
#
#    Texture_Organoid_Mito_Information.Measure.of.Correlation.2_256.3  \
# 0                                          -0.908726
# 1                                          -0.791176
# 2                                          -0.908707
# 3                                          -0.902352
# 4                                           1.342547
#
#    Texture_Organoid_Mito_Inverse.Difference.Moment_256.3  \
# 0                                           0.723078
# 1                                           0.718448
# 2                                           0.722927
# 3                                           0.722125
# 4                                          -0.941170
#
#    Texture_Organoid_Mito_Sum.Average_256.3  \
# 0                                -0.593903
# 1                                -0.589805
# 2                                -0.593751
# 3                                -0.593090
# 4                                 0.691929
#
#    Texture_Organoid_Mito_Sum.Entropy_256.3  \
# 0                                -0.733030
# 1                                -0.725724
# 2                                -0.732765
# 3                                -0.731511
# 4                                 0.914296
#
#    Texture_Organoid_Mito_Sum.Variance_256.3  \
# 0                                 -0.528032
# 1                                 -0.523691
# 2                                 -0.527863
# 3                                 -0.527244
# 4                                  0.408973
#
#    Texture_Organoid_Mito_Variance_256.3
# 0                             -0.561465
# 1                             -0.555467
# 2                             -0.561134
# 3                             -0.559971
# 4                              0.434582
#
# [5 rows x 1980 columns]

# %%
organoid_metadata_columns = [x for x in organoid_fs.columns if "Metadata" in x]
organoid_metadata_columns += [
    "Area.Size.Shape_Organoid_CENTER.X",
    "Area.Size.Shape_Organoid_CENTER.Y",
    "Area.Size.Shape_Organoid_CENTER.Z",
]
organoid_features_columns = [
    col for col in organoid_fs.columns if col not in organoid_metadata_columns
]
organoid_features_columns = [
    col for col in organoid_fs.columns if col not in organoid_metadata_columns
]
organoid_features_df = organoid_fs.drop(
    columns=organoid_metadata_columns, errors="ignore"
)

# %%
# stratification approach #1
organoid_well_agg = aggregate(
    population_df=organoid_fs,
    strata=[
        "Metadata_Well",
        "Metadata_treatment",
        "Metadata_Target",
        "Metadata_Class",
        "Metadata_Therapeutic_Categories",
    ],
    features=organoid_features_columns,
    operation="median",
)
organoid_well_agg.to_parquet(organoid_agg_well_output_path, index=False)

# stratification approach #2
organoid_consensus = aggregate(  # a.k.a. consensus
    population_df=organoid_fs,
    strata=[
        "Metadata_treatment",
        "Metadata_Target",
        "Metadata_Class",
        "Metadata_Therapeutic_Categories",
    ],
    features=organoid_features_columns,
    operation="median",
)
organoid_consensus.to_parquet(organoid_consensus_output_path, index=False)

# %%
organoid_well_agg.head()
# Out:
#   Metadata_Well Metadata_treatment      Metadata_Target  Metadata_Class  \
# 0           C10         Trametinib     MEK1/2 inhibitor  Small Molecule
# 1           C11      Staurosporine  Apoptosis induction  Small Molecule
# 2            C2      Staurosporine  Apoptosis induction  Small Molecule
# 3            C3          Onalespib      HSP90 inhibitor  Small Molecule
# 4            C4               DMSO              Control         Control
#
#   Metadata_Therapeutic_Categories  Area.Size.Shape_Organoid_VOLUME  \
# 0                Kinase Inhibitor                        -0.591452
# 1                    Experimental                        -0.501584
# 2                    Experimental                        -0.484823
# 3                 Investigational                        -0.318224
# 4                         Control                        -0.383653
#
#    Area.Size.Shape_Organoid_EXTENT  Area.Size.Shape_Organoid_EULER.NUMBER  \
# 0                        -1.230203                              -0.129210
# 1                         0.576996                              -0.439983
# 2                         1.111736                              -0.439983
# 3                         0.132529                              -0.422718
# 4                         0.847258                              -0.439983
#
#    Area.Size.Shape_Organoid_EQUIVALENT.DIAMETER  \
# 0                                     -1.113271
# 1                                     -0.244405
# 2                                     -0.187503
# 3                                      0.179282
# 4                                      0.068458
#
#    Colocalization_Organoid_AGP.ER_MEAN.CORRELATION.COEFF  ...  \
# 0                                          -1.338400      ...
# 1                                           1.078882      ...
# 2                                           0.129828      ...
# 3                                           0.229687      ...
# 4                                          -0.714151      ...
#
#    Texture_Organoid_Mito_Difference.Entropy_256.3  \
# 0                                       -0.798152
# 1                                       -0.536968
# 2                                        0.776953
# 3                                        0.055229
# 4                                       -0.234563
#
#    Texture_Organoid_Mito_Difference.Variance_256.3  \
# 0                                         0.726798
# 1                                         0.559472
# 2                                        -0.674829
# 3                                        -0.020141
# 4                                         0.272459
#
#    Texture_Organoid_Mito_Entropy_256.3  \
# 0                            -0.706602
# 1                            -0.512897
# 2                             0.401309
# 3                            -0.116865
# 4                            -0.323862
#
#    Texture_Organoid_Mito_Information.Measure.of.Correlation.1_256.3  \
# 0                                           1.173773
# 1                                          -0.492253
# 2                                           0.207120
# 3                                           0.162751
# 4                                           0.165533
#
#    Texture_Organoid_Mito_Information.Measure.of.Correlation.2_256.3  \
# 0                                          -0.897471
# 1                                          -0.172738
# 2                                          -0.057420
# 3                                          -0.305070
# 4                                          -0.433194
#
#    Texture_Organoid_Mito_Inverse.Difference.Moment_256.3  \
# 0                                           0.722397
# 1                                           0.558685
# 2                                          -0.695500
# 3                                          -0.023754
# 4                                           0.271977
#
#    Texture_Organoid_Mito_Sum.Average_256.3  \
# 0                                -0.593127
# 1                                -0.417298
# 2                                -0.047049
# 3                                -0.284274
# 4                                -0.318435
#
#    Texture_Organoid_Mito_Sum.Entropy_256.3  \
# 0                                -0.731915
# 1                                -0.520129
# 2                                 0.459399
# 3                                -0.085431
# 4                                -0.309889
#
#    Texture_Organoid_Mito_Sum.Variance_256.3  \
# 0                                 -0.527009
# 1                                 -0.297328
# 2                                 -0.244794
# 3                                 -0.377150
# 4                                 -0.307572
#
#    Texture_Organoid_Mito_Variance_256.3
# 0                             -0.559613
# 1                             -0.282938
# 2                             -0.151237
# 3                             -0.372186
# 4                             -0.339127
#
# [5 rows x 1969 columns]

# %%
organoid_consensus.head()
# Out:
#   Metadata_treatment                     Metadata_Target  Metadata_Class  \
# 0        Binimetinib                    MEK1/2 inhibitor  Small Molecule
# 1       Cabozantinib  receptor tyrosine kinase inhibitor  Small Molecule
# 2         Copanlisib                      PI3K inhibitor  Small Molecule
# 3               DMSO                             Control         Control
# 4            Digoxin               Na+/K+ pump inhibitor  Small Molecule
#
#   Metadata_Therapeutic_Categories  Area.Size.Shape_Organoid_VOLUME  \
# 0                Kinase Inhibitor                        -0.385050
# 1                Kinase Inhibitor                        -0.373091
# 2                Kinase Inhibitor                        -0.304822
# 3                         Control                        -0.459320
# 4              Cardiac Glycosides                        -0.354641
#
#    Area.Size.Shape_Organoid_EXTENT  Area.Size.Shape_Organoid_EULER.NUMBER  \
# 0                         0.336724                              -0.439983
# 1                         0.552631                              -0.439983
# 2                         0.300302                              -0.431350
# 3                         0.264174                              -0.422718
# 4                         0.648939                              -0.439983
#
#    Area.Size.Shape_Organoid_EQUIVALENT.DIAMETER  \
# 0                                      0.065562
# 1                                      0.089850
# 2                                      0.209167
# 3                                     -0.111352
# 4                                      0.124979
#
#    Colocalization_Organoid_AGP.ER_MEAN.CORRELATION.COEFF  \
# 0                                           0.228735
# 1                                           1.001985
# 2                                           0.962230
# 3                                           0.218597
# 4                                           0.362138
#
#    Colocalization_Organoid_AGP.ER_MEDIAN.CORRELATION.COEFF  ...  \
# 0                                           0.228735        ...
# 1                                           1.001985        ...
# 2                                           0.962230        ...
# 3                                           0.218597        ...
# 4                                           0.362138        ...
#
#    Texture_Organoid_Mito_Difference.Entropy_256.3  \
# 0                                        0.107344
# 1                                        0.131717
# 2                                        0.294554
# 3                                       -0.408411
# 4                                        0.110393
#
#    Texture_Organoid_Mito_Difference.Variance_256.3  \
# 0                                        -0.014896
# 1                                        -0.060752
# 2                                        -0.221053
# 3                                         0.438545
# 4                                        -0.061719
#
#    Texture_Organoid_Mito_Entropy_256.3  \
# 0                            -0.011921
# 1                            -0.010866
# 2                             0.107023
# 3                            -0.421052
# 4                            -0.024501
#
#    Texture_Organoid_Mito_Information.Measure.of.Correlation.1_256.3  \
# 0                                          -0.410368
# 1                                          -0.878018
# 2                                          -0.214056
# 3                                           0.169433
# 4                                          -0.227871
#
#    Texture_Organoid_Mito_Information.Measure.of.Correlation.2_256.3  \
# 0                                          -0.039506
# 1                                           0.388157
# 2                                           0.455153
# 3                                          -0.416510
# 4                                           0.244182
#
#    Texture_Organoid_Mito_Inverse.Difference.Moment_256.3  \
# 0                                          -0.006378
# 1                                          -0.063349
# 2                                          -0.225346
# 3                                           0.439834
# 4                                          -0.062930
#
#    Texture_Organoid_Mito_Sum.Average_256.3  \
# 0                                -0.324999
# 1                                -0.078009
# 2                                 0.024684
# 3                                -0.445022
# 4                                -0.325151
#
#    Texture_Organoid_Mito_Sum.Entropy_256.3  \
# 0                                 0.021132
# 1                                 0.019869
# 2                                 0.146524
# 3                                -0.425364
# 4                                 0.004068
#
#    Texture_Organoid_Mito_Sum.Variance_256.3  \
# 0                                 -0.345290
# 1                                 -0.048137
# 2                                 -0.066725
# 3                                 -0.417596
# 4                                 -0.396754
#
#    Texture_Organoid_Mito_Variance_256.3
# 0                             -0.325798
# 1                              0.017315
# 2                             -0.003940
# 3                             -0.413548
# 4                             -0.372238
#
# [5 rows x 1968 columns]
