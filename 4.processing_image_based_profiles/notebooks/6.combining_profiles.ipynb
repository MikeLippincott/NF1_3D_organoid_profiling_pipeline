# %% [markdown]
# This notebook combines all well fovs for each patient into a single file.

# %%
import argparse
import os
import pathlib
import sys

import duckdb
import pandas as pd
from arg_parsing_utils import parse_args
from notebook_init_utils import bandicoot_check, init_notebook

root_dir, in_notebook = init_notebook()

profile_base_dir = bandicoot_check(
    pathlib.Path(os.path.expanduser("~/mnt/bandicoot/NF1_organoid_data")).resolve(),
    root_dir,
)

# %%
if not in_notebook:
    args = parse_args()
    patient = args["patient"]
    image_based_profiles_subparent_name = args["image_based_profiles_subparent_name"]

else:
    patient = "NF0014_T1"
    image_based_profiles_subparent_name = "convolution_1_image_based_profiles"

# %%
# set paths
profiles_path = pathlib.Path(
    f"{profile_base_dir}/data/{patient}/{image_based_profiles_subparent_name}/0.converted_profiles"
).resolve(strict=True)
# output_paths
sc_merged_output_path = pathlib.Path(
    f"{profile_base_dir}/data/{patient}/{image_based_profiles_subparent_name}/1.combined_profiles/sc.parquet"
).resolve()
organoid_merged_output_path = pathlib.Path(
    f"{profile_base_dir}/data/{patient}/{image_based_profiles_subparent_name}/1.combined_profiles/organoid.parquet"
).resolve()
organoid_merged_output_path.parent.mkdir(parents=True, exist_ok=True)

# %%
# get all profiles in the directory recursively
profiles = list(profiles_path.glob("**/*.parquet"))
# filter out profiles that are not related
profiles = [x for x in profiles if "related" in str(x)]

# %%
sc_profiles = [str(x) for x in profiles if "sc" in str(x.name)]
organoid_profiles = [str(x) for x in profiles if "organoid" in str(x.name)]

# %%
# for p in sc_profiles:
#     try:
#         df = pd.read_parquet(p)['Intensity_Nuclei_DNA_MAX.Z_y']
#         print(f"Read {p} with shape {df.shape}")
#     except Exception as e:
# pass

for col in pd.read_parquet(
    pathlib.Path(
        os.path.expanduser(
            f"~/mnt/bandicoot/NF1_organoid_data/data/NF0014_T1/{image_based_profiles_subparent_name}/0.converted_profiles/C4-2/sc_profiles_C4-2_related.parquet"
        )
    )
).columns:
    if "intensity" in col.lower():
        print(col)
# Out:
# Intensity_Nuclei_AGP_CM.X
# Intensity_Nuclei_AGP_CM.Y
# Intensity_Nuclei_AGP_CM.Z
# Intensity_Nuclei_AGP_CMI.X
# Intensity_Nuclei_AGP_CMI.Y
# Intensity_Nuclei_AGP_CMI.Z
# Intensity_Nuclei_AGP_DIFF.X
# Intensity_Nuclei_AGP_DIFF.Y
# Intensity_Nuclei_AGP_DIFF.Z
# Intensity_Nuclei_AGP_EDGE.COUNT
# Intensity_Nuclei_AGP_I.X
# Intensity_Nuclei_AGP_I.Y
# Intensity_Nuclei_AGP_I.Z
# Intensity_Nuclei_AGP_INTEGRATED.INTENSITY
# Intensity_Nuclei_AGP_INTEGRATED.INTENSITY.EDGE
# Intensity_Nuclei_AGP_LOWER.QUARTILE.INTENSITY
# Intensity_Nuclei_AGP_MAD.INTENSITY
# Intensity_Nuclei_AGP_MASS.DISPLACEMENT
# Intensity_Nuclei_AGP_MAX.INTENSITY
# Intensity_Nuclei_AGP_MAX.INTENSITY.EDGE
# Intensity_Nuclei_AGP_MAX.X
# Intensity_Nuclei_AGP_MAX.Y
# Intensity_Nuclei_AGP_MAX.Z
# Intensity_Nuclei_AGP_MEAN.INTENSITY
# Intensity_Nuclei_AGP_MEAN.INTENSITY.EDGE
# Intensity_Nuclei_AGP_MEDIAN.INTENSITY
# Intensity_Nuclei_AGP_MIN.INTENSITY
# Intensity_Nuclei_AGP_MIN.INTENSITY.EDGE
# Intensity_Nuclei_AGP_STD.INTENSITY
# Intensity_Nuclei_AGP_STD.INTENSITY.EDGE
# Intensity_Nuclei_AGP_UPPER.QUARTILE.INTENSITY
# Intensity_Nuclei_AGP_VOLUME
# Intensity_Nuclei_DNA_CM.X
# Intensity_Nuclei_DNA_CM.Y
# Intensity_Nuclei_DNA_CM.Z
# Intensity_Nuclei_DNA_CMI.X
# Intensity_Nuclei_DNA_CMI.Y
# Intensity_Nuclei_DNA_CMI.Z
# Intensity_Nuclei_DNA_DIFF.X
# Intensity_Nuclei_DNA_DIFF.Y
# Intensity_Nuclei_DNA_DIFF.Z
# Intensity_Nuclei_DNA_EDGE.COUNT
# Intensity_Nuclei_DNA_I.X
# Intensity_Nuclei_DNA_I.Y
# Intensity_Nuclei_DNA_I.Z
# Intensity_Nuclei_DNA_INTEGRATED.INTENSITY
# Intensity_Nuclei_DNA_INTEGRATED.INTENSITY.EDGE
# Intensity_Nuclei_DNA_LOWER.QUARTILE.INTENSITY
# Intensity_Nuclei_DNA_MAD.INTENSITY
# Intensity_Nuclei_DNA_MASS.DISPLACEMENT
# Intensity_Nuclei_DNA_MAX.INTENSITY
# Intensity_Nuclei_DNA_MAX.INTENSITY.EDGE
# Intensity_Nuclei_DNA_MAX.X
# Intensity_Nuclei_DNA_MAX.Y
# Intensity_Nuclei_DNA_MAX.Z
# Intensity_Nuclei_DNA_MEAN.INTENSITY
# Intensity_Nuclei_DNA_MEAN.INTENSITY.EDGE
# Intensity_Nuclei_DNA_MEDIAN.INTENSITY
# Intensity_Nuclei_DNA_MIN.INTENSITY
# Intensity_Nuclei_DNA_MIN.INTENSITY.EDGE
# Intensity_Nuclei_DNA_STD.INTENSITY
# Intensity_Nuclei_DNA_STD.INTENSITY.EDGE
# Intensity_Nuclei_DNA_UPPER.QUARTILE.INTENSITY
# Intensity_Nuclei_DNA_VOLUME
# Intensity_Nuclei_ER_CM.X
# Intensity_Nuclei_ER_CM.Y
# Intensity_Nuclei_ER_CM.Z
# Intensity_Nuclei_ER_CMI.X
# Intensity_Nuclei_ER_CMI.Y
# Intensity_Nuclei_ER_CMI.Z
# Intensity_Nuclei_ER_DIFF.X
# Intensity_Nuclei_ER_DIFF.Y
# Intensity_Nuclei_ER_DIFF.Z
# Intensity_Nuclei_ER_EDGE.COUNT
# Intensity_Nuclei_ER_I.X
# Intensity_Nuclei_ER_I.Y
# Intensity_Nuclei_ER_I.Z
# Intensity_Nuclei_ER_INTEGRATED.INTENSITY
# Intensity_Nuclei_ER_INTEGRATED.INTENSITY.EDGE
# Intensity_Nuclei_ER_LOWER.QUARTILE.INTENSITY
# Intensity_Nuclei_ER_MAD.INTENSITY
# Intensity_Nuclei_ER_MASS.DISPLACEMENT
# Intensity_Nuclei_ER_MAX.INTENSITY
# Intensity_Nuclei_ER_MAX.INTENSITY.EDGE
# Intensity_Nuclei_ER_MAX.X
# Intensity_Nuclei_ER_MAX.Y
# Intensity_Nuclei_ER_MAX.Z
# Intensity_Nuclei_ER_MEAN.INTENSITY
# Intensity_Nuclei_ER_MEAN.INTENSITY.EDGE
# Intensity_Nuclei_ER_MEDIAN.INTENSITY
# Intensity_Nuclei_ER_MIN.INTENSITY
# Intensity_Nuclei_ER_MIN.INTENSITY.EDGE
# Intensity_Nuclei_ER_STD.INTENSITY
# Intensity_Nuclei_ER_STD.INTENSITY.EDGE
# Intensity_Nuclei_ER_UPPER.QUARTILE.INTENSITY
# Intensity_Nuclei_ER_VOLUME
# Intensity_Nuclei_Mito_CM.X
# Intensity_Nuclei_Mito_CM.Y
# Intensity_Nuclei_Mito_CM.Z
# Intensity_Nuclei_Mito_CMI.X
# Intensity_Nuclei_Mito_CMI.Y
# Intensity_Nuclei_Mito_CMI.Z
# Intensity_Nuclei_Mito_DIFF.X
# Intensity_Nuclei_Mito_DIFF.Y
# Intensity_Nuclei_Mito_DIFF.Z
# Intensity_Nuclei_Mito_EDGE.COUNT
# Intensity_Nuclei_Mito_I.X
# Intensity_Nuclei_Mito_I.Y
# Intensity_Nuclei_Mito_I.Z
# Intensity_Nuclei_Mito_INTEGRATED.INTENSITY
# Intensity_Nuclei_Mito_INTEGRATED.INTENSITY.EDGE
# Intensity_Nuclei_Mito_LOWER.QUARTILE.INTENSITY
# Intensity_Nuclei_Mito_MAD.INTENSITY
# Intensity_Nuclei_Mito_MASS.DISPLACEMENT
# Intensity_Nuclei_Mito_MAX.INTENSITY
# Intensity_Nuclei_Mito_MAX.INTENSITY.EDGE
# Intensity_Nuclei_Mito_MAX.X
# Intensity_Nuclei_Mito_MAX.Y
# Intensity_Nuclei_Mito_MAX.Z
# Intensity_Nuclei_Mito_MEAN.INTENSITY
# Intensity_Nuclei_Mito_MEAN.INTENSITY.EDGE
# Intensity_Nuclei_Mito_MEDIAN.INTENSITY
# Intensity_Nuclei_Mito_MIN.INTENSITY
# Intensity_Nuclei_Mito_MIN.INTENSITY.EDGE
# Intensity_Nuclei_Mito_STD.INTENSITY
# Intensity_Nuclei_Mito_STD.INTENSITY.EDGE
# Intensity_Nuclei_Mito_UPPER.QUARTILE.INTENSITY
# Intensity_Nuclei_Mito_VOLUME
# Intensity_Cell_AGP_CM.X
# Intensity_Cell_AGP_CM.Y
# Intensity_Cell_AGP_CM.Z
# Intensity_Cell_AGP_CMI.X
# Intensity_Cell_AGP_CMI.Y
# Intensity_Cell_AGP_CMI.Z
# Intensity_Cell_AGP_DIFF.X
# Intensity_Cell_AGP_DIFF.Y
# Intensity_Cell_AGP_DIFF.Z
# Intensity_Cell_AGP_EDGE.COUNT
# Intensity_Cell_AGP_I.X
# Intensity_Cell_AGP_I.Y
# Intensity_Cell_AGP_I.Z
# Intensity_Cell_AGP_INTEGRATED.INTENSITY
# Intensity_Cell_AGP_INTEGRATED.INTENSITY.EDGE
# Intensity_Cell_AGP_LOWER.QUARTILE.INTENSITY
# Intensity_Cell_AGP_MAD.INTENSITY
# Intensity_Cell_AGP_MASS.DISPLACEMENT
# Intensity_Cell_AGP_MAX.INTENSITY
# Intensity_Cell_AGP_MAX.INTENSITY.EDGE
# Intensity_Cell_AGP_MAX.X
# Intensity_Cell_AGP_MAX.Y
# Intensity_Cell_AGP_MAX.Z
# Intensity_Cell_AGP_MEAN.INTENSITY
# Intensity_Cell_AGP_MEAN.INTENSITY.EDGE
# Intensity_Cell_AGP_MEDIAN.INTENSITY
# Intensity_Cell_AGP_MIN.INTENSITY
# Intensity_Cell_AGP_MIN.INTENSITY.EDGE
# Intensity_Cell_AGP_STD.INTENSITY
# Intensity_Cell_AGP_STD.INTENSITY.EDGE
# Intensity_Cell_AGP_UPPER.QUARTILE.INTENSITY
# Intensity_Cell_AGP_VOLUME
# Intensity_Cell_DNA_CM.X
# Intensity_Cell_DNA_CM.Y
# Intensity_Cell_DNA_CM.Z
# Intensity_Cell_DNA_CMI.X
# Intensity_Cell_DNA_CMI.Y
# Intensity_Cell_DNA_CMI.Z
# Intensity_Cell_DNA_DIFF.X
# Intensity_Cell_DNA_DIFF.Y
# Intensity_Cell_DNA_DIFF.Z
# Intensity_Cell_DNA_EDGE.COUNT
# Intensity_Cell_DNA_I.X
# Intensity_Cell_DNA_I.Y
# Intensity_Cell_DNA_I.Z
# Intensity_Cell_DNA_INTEGRATED.INTENSITY
# Intensity_Cell_DNA_INTEGRATED.INTENSITY.EDGE
# Intensity_Cell_DNA_LOWER.QUARTILE.INTENSITY
# Intensity_Cell_DNA_MAD.INTENSITY
# Intensity_Cell_DNA_MASS.DISPLACEMENT
# Intensity_Cell_DNA_MAX.INTENSITY
# Intensity_Cell_DNA_MAX.INTENSITY.EDGE
# Intensity_Cell_DNA_MAX.X
# Intensity_Cell_DNA_MAX.Y
# Intensity_Cell_DNA_MAX.Z
# Intensity_Cell_DNA_MEAN.INTENSITY
# Intensity_Cell_DNA_MEAN.INTENSITY.EDGE
# Intensity_Cell_DNA_MEDIAN.INTENSITY
# Intensity_Cell_DNA_MIN.INTENSITY
# Intensity_Cell_DNA_MIN.INTENSITY.EDGE
# Intensity_Cell_DNA_STD.INTENSITY
# Intensity_Cell_DNA_STD.INTENSITY.EDGE
# Intensity_Cell_DNA_UPPER.QUARTILE.INTENSITY
# Intensity_Cell_DNA_VOLUME
# Intensity_Cell_ER_CM.X
# Intensity_Cell_ER_CM.Y
# Intensity_Cell_ER_CM.Z
# Intensity_Cell_ER_CMI.X
# Intensity_Cell_ER_CMI.Y
# Intensity_Cell_ER_CMI.Z
# Intensity_Cell_ER_DIFF.X
# Intensity_Cell_ER_DIFF.Y
# Intensity_Cell_ER_DIFF.Z
# Intensity_Cell_ER_EDGE.COUNT
# Intensity_Cell_ER_I.X
# Intensity_Cell_ER_I.Y
# Intensity_Cell_ER_I.Z
# Intensity_Cell_ER_INTEGRATED.INTENSITY
# Intensity_Cell_ER_INTEGRATED.INTENSITY.EDGE
# Intensity_Cell_ER_LOWER.QUARTILE.INTENSITY
# Intensity_Cell_ER_MAD.INTENSITY
# Intensity_Cell_ER_MASS.DISPLACEMENT
# Intensity_Cell_ER_MAX.INTENSITY
# Intensity_Cell_ER_MAX.INTENSITY.EDGE
# Intensity_Cell_ER_MAX.X
# Intensity_Cell_ER_MAX.Y
# Intensity_Cell_ER_MAX.Z
# Intensity_Cell_ER_MEAN.INTENSITY
# Intensity_Cell_ER_MEAN.INTENSITY.EDGE
# Intensity_Cell_ER_MEDIAN.INTENSITY
# Intensity_Cell_ER_MIN.INTENSITY
# Intensity_Cell_ER_MIN.INTENSITY.EDGE
# Intensity_Cell_ER_STD.INTENSITY
# Intensity_Cell_ER_STD.INTENSITY.EDGE
# Intensity_Cell_ER_UPPER.QUARTILE.INTENSITY
# Intensity_Cell_ER_VOLUME
# Intensity_Cell_Mito_CM.X
# Intensity_Cell_Mito_CM.Y
# Intensity_Cell_Mito_CM.Z
# Intensity_Cell_Mito_CMI.X
# Intensity_Cell_Mito_CMI.Y
# Intensity_Cell_Mito_CMI.Z
# Intensity_Cell_Mito_DIFF.X
# Intensity_Cell_Mito_DIFF.Y
# Intensity_Cell_Mito_DIFF.Z
# Intensity_Cell_Mito_EDGE.COUNT
# Intensity_Cell_Mito_I.X
# Intensity_Cell_Mito_I.Y
# Intensity_Cell_Mito_I.Z
# Intensity_Cell_Mito_INTEGRATED.INTENSITY
# Intensity_Cell_Mito_INTEGRATED.INTENSITY.EDGE
# Intensity_Cell_Mito_LOWER.QUARTILE.INTENSITY
# Intensity_Cell_Mito_MAD.INTENSITY
# Intensity_Cell_Mito_MASS.DISPLACEMENT
# Intensity_Cell_Mito_MAX.INTENSITY
# Intensity_Cell_Mito_MAX.INTENSITY.EDGE
# Intensity_Cell_Mito_MAX.X
# Intensity_Cell_Mito_MAX.Y
# Intensity_Cell_Mito_MAX.Z
# Intensity_Cell_Mito_MEAN.INTENSITY
# Intensity_Cell_Mito_MEAN.INTENSITY.EDGE
# Intensity_Cell_Mito_MEDIAN.INTENSITY
# Intensity_Cell_Mito_MIN.INTENSITY
# Intensity_Cell_Mito_MIN.INTENSITY.EDGE
# Intensity_Cell_Mito_STD.INTENSITY
# Intensity_Cell_Mito_STD.INTENSITY.EDGE
# Intensity_Cell_Mito_UPPER.QUARTILE.INTENSITY
# Intensity_Cell_Mito_VOLUME
# Intensity_Cytoplasm_AGP_CM.X
# Intensity_Cytoplasm_AGP_CM.Y
# Intensity_Cytoplasm_AGP_CM.Z
# Intensity_Cytoplasm_AGP_CMI.X
# Intensity_Cytoplasm_AGP_CMI.Y
# Intensity_Cytoplasm_AGP_CMI.Z
# Intensity_Cytoplasm_AGP_DIFF.X
# Intensity_Cytoplasm_AGP_DIFF.Y
# Intensity_Cytoplasm_AGP_DIFF.Z
# Intensity_Cytoplasm_AGP_EDGE.COUNT
# Intensity_Cytoplasm_AGP_I.X
# Intensity_Cytoplasm_AGP_I.Y
# Intensity_Cytoplasm_AGP_I.Z
# Intensity_Cytoplasm_AGP_INTEGRATED.INTENSITY
# Intensity_Cytoplasm_AGP_INTEGRATED.INTENSITY.EDGE
# Intensity_Cytoplasm_AGP_LOWER.QUARTILE.INTENSITY
# Intensity_Cytoplasm_AGP_MAD.INTENSITY
# Intensity_Cytoplasm_AGP_MASS.DISPLACEMENT
# Intensity_Cytoplasm_AGP_MAX.INTENSITY
# Intensity_Cytoplasm_AGP_MAX.INTENSITY.EDGE
# Intensity_Cytoplasm_AGP_MAX.X
# Intensity_Cytoplasm_AGP_MAX.Y
# Intensity_Cytoplasm_AGP_MAX.Z
# Intensity_Cytoplasm_AGP_MEAN.INTENSITY
# Intensity_Cytoplasm_AGP_MEAN.INTENSITY.EDGE
# Intensity_Cytoplasm_AGP_MEDIAN.INTENSITY
# Intensity_Cytoplasm_AGP_MIN.INTENSITY
# Intensity_Cytoplasm_AGP_MIN.INTENSITY.EDGE
# Intensity_Cytoplasm_AGP_STD.INTENSITY
# Intensity_Cytoplasm_AGP_STD.INTENSITY.EDGE
# Intensity_Cytoplasm_AGP_UPPER.QUARTILE.INTENSITY
# Intensity_Cytoplasm_AGP_VOLUME
# Intensity_Cytoplasm_DNA_CM.X
# Intensity_Cytoplasm_DNA_CM.Y
# Intensity_Cytoplasm_DNA_CM.Z
# Intensity_Cytoplasm_DNA_CMI.X
# Intensity_Cytoplasm_DNA_CMI.Y
# Intensity_Cytoplasm_DNA_CMI.Z
# Intensity_Cytoplasm_DNA_DIFF.X
# Intensity_Cytoplasm_DNA_DIFF.Y
# Intensity_Cytoplasm_DNA_DIFF.Z
# Intensity_Cytoplasm_DNA_EDGE.COUNT
# Intensity_Cytoplasm_DNA_I.X
# Intensity_Cytoplasm_DNA_I.Y
# Intensity_Cytoplasm_DNA_I.Z
# Intensity_Cytoplasm_DNA_INTEGRATED.INTENSITY
# Intensity_Cytoplasm_DNA_INTEGRATED.INTENSITY.EDGE
# Intensity_Cytoplasm_DNA_LOWER.QUARTILE.INTENSITY
# Intensity_Cytoplasm_DNA_MAD.INTENSITY
# Intensity_Cytoplasm_DNA_MASS.DISPLACEMENT
# Intensity_Cytoplasm_DNA_MAX.INTENSITY
# Intensity_Cytoplasm_DNA_MAX.INTENSITY.EDGE
# Intensity_Cytoplasm_DNA_MAX.X
# Intensity_Cytoplasm_DNA_MAX.Y
# Intensity_Cytoplasm_DNA_MAX.Z
# Intensity_Cytoplasm_DNA_MEAN.INTENSITY
# Intensity_Cytoplasm_DNA_MEAN.INTENSITY.EDGE
# Intensity_Cytoplasm_DNA_MEDIAN.INTENSITY
# Intensity_Cytoplasm_DNA_MIN.INTENSITY
# Intensity_Cytoplasm_DNA_MIN.INTENSITY.EDGE
# Intensity_Cytoplasm_DNA_STD.INTENSITY
# Intensity_Cytoplasm_DNA_STD.INTENSITY.EDGE
# Intensity_Cytoplasm_DNA_UPPER.QUARTILE.INTENSITY
# Intensity_Cytoplasm_DNA_VOLUME
# Intensity_Cytoplasm_ER_CM.X
# Intensity_Cytoplasm_ER_CM.Y
# Intensity_Cytoplasm_ER_CM.Z
# Intensity_Cytoplasm_ER_CMI.X
# Intensity_Cytoplasm_ER_CMI.Y
# Intensity_Cytoplasm_ER_CMI.Z
# Intensity_Cytoplasm_ER_DIFF.X
# Intensity_Cytoplasm_ER_DIFF.Y
# Intensity_Cytoplasm_ER_DIFF.Z
# Intensity_Cytoplasm_ER_EDGE.COUNT
# Intensity_Cytoplasm_ER_I.X
# Intensity_Cytoplasm_ER_I.Y
# Intensity_Cytoplasm_ER_I.Z
# Intensity_Cytoplasm_ER_INTEGRATED.INTENSITY
# Intensity_Cytoplasm_ER_INTEGRATED.INTENSITY.EDGE
# Intensity_Cytoplasm_ER_LOWER.QUARTILE.INTENSITY
# Intensity_Cytoplasm_ER_MAD.INTENSITY
# Intensity_Cytoplasm_ER_MASS.DISPLACEMENT
# Intensity_Cytoplasm_ER_MAX.INTENSITY
# Intensity_Cytoplasm_ER_MAX.INTENSITY.EDGE
# Intensity_Cytoplasm_ER_MAX.X
# Intensity_Cytoplasm_ER_MAX.Y
# Intensity_Cytoplasm_ER_MAX.Z
# Intensity_Cytoplasm_ER_MEAN.INTENSITY
# Intensity_Cytoplasm_ER_MEAN.INTENSITY.EDGE
# Intensity_Cytoplasm_ER_MEDIAN.INTENSITY
# Intensity_Cytoplasm_ER_MIN.INTENSITY
# Intensity_Cytoplasm_ER_MIN.INTENSITY.EDGE
# Intensity_Cytoplasm_ER_STD.INTENSITY
# Intensity_Cytoplasm_ER_STD.INTENSITY.EDGE
# Intensity_Cytoplasm_ER_UPPER.QUARTILE.INTENSITY
# Intensity_Cytoplasm_ER_VOLUME
# Intensity_Cytoplasm_Mito_CM.X
# Intensity_Cytoplasm_Mito_CM.Y
# Intensity_Cytoplasm_Mito_CM.Z
# Intensity_Cytoplasm_Mito_CMI.X
# Intensity_Cytoplasm_Mito_CMI.Y
# Intensity_Cytoplasm_Mito_CMI.Z
# Intensity_Cytoplasm_Mito_DIFF.X
# Intensity_Cytoplasm_Mito_DIFF.Y
# Intensity_Cytoplasm_Mito_DIFF.Z
# Intensity_Cytoplasm_Mito_EDGE.COUNT
# Intensity_Cytoplasm_Mito_I.X
# Intensity_Cytoplasm_Mito_I.Y
# Intensity_Cytoplasm_Mito_I.Z
# Intensity_Cytoplasm_Mito_INTEGRATED.INTENSITY
# Intensity_Cytoplasm_Mito_INTEGRATED.INTENSITY.EDGE
# Intensity_Cytoplasm_Mito_LOWER.QUARTILE.INTENSITY
# Intensity_Cytoplasm_Mito_MAD.INTENSITY
# Intensity_Cytoplasm_Mito_MASS.DISPLACEMENT
# Intensity_Cytoplasm_Mito_MAX.INTENSITY
# Intensity_Cytoplasm_Mito_MAX.INTENSITY.EDGE
# Intensity_Cytoplasm_Mito_MAX.X
# Intensity_Cytoplasm_Mito_MAX.Y
# Intensity_Cytoplasm_Mito_MAX.Z
# Intensity_Cytoplasm_Mito_MEAN.INTENSITY
# Intensity_Cytoplasm_Mito_MEAN.INTENSITY.EDGE
# Intensity_Cytoplasm_Mito_MEDIAN.INTENSITY
# Intensity_Cytoplasm_Mito_MIN.INTENSITY
# Intensity_Cytoplasm_Mito_MIN.INTENSITY.EDGE
# Intensity_Cytoplasm_Mito_STD.INTENSITY
# Intensity_Cytoplasm_Mito_STD.INTENSITY.EDGE
# Intensity_Cytoplasm_Mito_UPPER.QUARTILE.INTENSITY
# Intensity_Cytoplasm_Mito_VOLUME

# %%
# concat all sc profiles with duckdb
with duckdb.connect() as conn:
    sc_profile = conn.execute(
        f"SELECT * FROM read_parquet({sc_profiles}, union_by_name=true)"
    ).df()
    organoid_profile = conn.execute(
        f"SELECT * FROM read_parquet({organoid_profiles}, union_by_name=true)"
    ).df()
print(f"Single-cell profiles concatenated. Shape: {sc_profile.shape}")
print(f"Organoid profiles concatenated. Shape: {organoid_profile.shape}")
# drop imageset_1 and image_set_2 columns if they exist
if "image_set_1" in sc_profile.columns:
    sc_profile = sc_profile.drop(columns=["image_set_1"])
if "image_set_2" in sc_profile.columns:
    sc_profile = sc_profile.drop(columns=["image_set_2"])
if "image_set_1" in organoid_profile.columns:
    organoid_profile = organoid_profile.drop(columns=["image_set_1"])
if "image_set_2" in organoid_profile.columns:
    organoid_profile = organoid_profile.drop(columns=["image_set_2"])
# Out:
# Single-cell profiles concatenated. Shape: (30, 1360)
# Organoid profiles concatenated. Shape: (1, 454)

# %% [markdown]
# ## Remove all BF channels

# %%
print(f"Single-cell profiles shape: {sc_profile.shape}")
list_of_columns_to_drop = [col for col in sc_profile.columns if "BF" in col]
sc_profile = sc_profile.drop(columns=list_of_columns_to_drop)
print(f"Single-cell profiles shape after dropping BF channels: {sc_profile.shape}")

print(f"Organoid profiles shape: {organoid_profile.shape}")
list_of_columns_to_drop = [col for col in organoid_profile.columns if "BF" in col]
organoid_profile = organoid_profile.drop(columns=list_of_columns_to_drop)
print(f"Organoid profiles shape after dropping BF channels: {organoid_profile.shape}")
# Out:
# Single-cell profiles shape: (30, 1358)
# Single-cell profiles shape after dropping BF channels: (30, 1358)
# Organoid profiles shape: (1, 454)
# Organoid profiles shape after dropping BF channels: (1, 454)

# %%
sc_profile.to_parquet(sc_merged_output_path, index=False)
organoid_profile.to_parquet(organoid_merged_output_path, index=False)
print(f"Single-cell profiles saved to {sc_merged_output_path}")
print(f"Organoid profiles saved to {organoid_merged_output_path}")
# Out:
# Single-cell profiles saved to /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0014_T1/convolution_1_image_based_profiles/1.combined_profiles/sc.parquet
# Organoid profiles saved to /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0014_T1/convolution_1_image_based_profiles/1.combined_profiles/organoid.parquet

# %%
sc_profile
# Out:
#     object_id image_set  parent_organoid  Area.Size.Shape_Nuclei_VOLUME  \
# 0           2      C4-2               32                         5995.0
# 1          18      C4-2               32                        28163.0
# 2          28      C4-2               32                       125455.0
# 3          29      C4-2               32                        66761.0
# 4          33      C4-2               32                       128119.0
# 5          39      C4-2               32                        12965.0
# 6          48      C4-2               32                        83239.0
# 7          57      C4-2               32                        79716.0
# 8          66      C4-2               32                        82275.0
# 9          85      C4-2               32                        89227.0
# 10         87      C4-2               32                        82394.0
# 11        104      C4-2               32                        82911.0
# 12        117      C4-2               32                       138638.0
# 13        120      C4-2               32                       120300.0
# 14        134      C4-2               32                       119048.0
# 15        148      C4-2               32                       102519.0
# 16        154      C4-2               32                       128133.0
# 17        177      C4-2               32                        77051.0
# 18        186      C4-2               32                       113468.0
# 19        188      C4-2               32                        67636.0
# 20        195      C4-2               32                        67361.0
# 21        196      C4-2               32                        76399.0
# 22        200      C4-2               32                       116895.0
# 23        206      C4-2               32                        32299.0
# 24        213      C4-2               32                        91237.0
# 25        214      C4-2               32                        74953.0
# 26        215      C4-2               32                       165696.0
# 27        224      C4-2               32                        69382.0
# 28        253      C4-2               32                       102568.0
# 29        255      C4-2               32                       121100.0
#
#     Area.Size.Shape_Nuclei_CENTER.X  Area.Size.Shape_Nuclei_CENTER.Y  \
# 0                        847.588806                        74.060219
# 1                        508.470001                       255.540817
# 2                        912.757629                       419.849945
# 3                        409.968811                       652.169250
# 4                        693.761047                       423.789062
# 5                        175.754959                       363.513214
# 6                        742.896912                       386.984192
# 7                        506.548248                       557.989990
# 8                        418.282196                       545.677307
# 9                        752.275391                       542.383301
# 10                       951.894043                       707.663635
# 11                       565.255066                       803.025452
# 12                       684.969727                       763.348450
# 13                       451.631836                       619.376648
# 14                       819.516296                       742.205139
# 15                       562.425537                       381.260864
# 16                       835.648438                       761.884766
# 17                       697.733276                       336.403259
# 18                       864.167908                       347.680511
# 19                       646.878845                       589.963623
# 20                       702.847412                       676.787354
# 21                       610.931152                       519.203369
# 22                       582.261780                       279.367401
# 23                      1025.521606                       563.301697
# 24                       420.082550                       429.903137
# 25                       762.275940                       518.769043
# 26                       625.541687                       638.335693
# 27                       698.601807                       502.722107
# 28                       475.355835                       713.091431
# 29                       388.528229                       310.892700
#
#     Area.Size.Shape_Nuclei_CENTER.Z  Area.Size.Shape_Nuclei_BBOX.VOLUME  \
# 0                          0.000000                              7304.0
# 1                          1.012534                             38610.0
# 2                         16.152229                            192600.0
# 3                          4.913228                            973760.0
# 4                         19.189606                            334152.0
# 5                          3.827227                             19600.0
# 6                          4.943344                            116748.0
# 7                          4.390549                            111744.0
# 8                         13.582315                            144200.0
# 9                         17.870554                            135720.0
# 10                        14.280360                            128249.0
# 11                         5.605613                            142680.0
# 12                         7.567399                           2710448.0
# 13                        19.027971                            174636.0
# 14                        20.274292                            184464.0
# 15                        21.886227                            154187.0
# 16                         8.761935                            188976.0
# 17                        24.396244                            109888.0
# 18                        10.889405                            183976.0
# 19                         7.014696                            122500.0
# 20                        26.249847                             95942.0
# 21                        25.179230                            129426.0
# 22                        10.468891                            151200.0
# 23                        27.808571                             51520.0
# 24                        11.118844                            129591.0
# 25                        28.645926                            101104.0
# 26                        17.774973                            391000.0
# 27                         9.494509                            133575.0
# 28                        10.341179                            719800.0
# 29                        10.862791                            191360.0
#
#     Area.Size.Shape_Nuclei_MIN.X  Area.Size.Shape_Nuclei_MAX.X  ...  \
# 0                          804.0                         892.0  ...
# 1                          453.0                         563.0  ...
# 2                          858.0                         965.0  ...
# 3                          355.0                         534.0  ...
# 4                          639.0                         758.0  ...
# 5                          146.0                         202.0  ...
# 6                          671.0                         812.0  ...
# 7                          456.0                         553.0  ...
# 8                          349.0                         489.0  ...
# 9                          692.0                         812.0  ...
# 10                         906.0                         995.0  ...
# 11                         505.0                         628.0  ...
# 12                         453.0                         767.0  ...
# 13                         378.0                         525.0  ...
# 14                         756.0                         882.0  ...
# 15                         509.0                         616.0  ...
# 16                         773.0                         897.0  ...
# 17                         648.0                         749.0  ...
# 18                         805.0                         927.0  ...
# 19                         586.0                         711.0  ...
# 20                         652.0                         750.0  ...
# 21                         556.0                         667.0  ...
# 22                         529.0                         634.0  ...
# 23                         973.0                        1065.0  ...
# 24                         371.0                         470.0  ...
# 25                         689.0                         831.0  ...
# 26                         570.0                         685.0  ...
# 27                         635.0                         772.0  ...
# 28                         420.0                         538.0  ...
# 29                         332.0                         447.0  ...
#
#     Texture_Cytoplasm_Mito_Difference.Entropy_256.3  \
# 0                                          0.015759
# 1                                          0.031411
# 2                                          0.094189
# 3                                          0.032753
# 4                                          0.088130
# 5                                          0.005109
# 6                                          0.042261
# 7                                          0.031206
# 8                                          0.039205
# 9                                          0.055923
# 10                                         0.107650
# 11                                         0.041595
# 12                                         0.088744
# 13                                         0.120368
# 14                                         0.105618
# 15                                         0.176309
# 16                                         0.038766
# 17                                         0.039449
# 18                                         0.110743
# 19                                         0.032161
# 20                                         0.054997
# 21                                         0.040117
# 22                                         0.048891
# 23                                         0.050815
# 24                                         0.082665
# 25                                         0.026777
# 26                                         0.093232
# 27                                         0.035284
# 28                                         0.091843
# 29                                         0.147373
#
#     Texture_Cytoplasm_Mito_Difference.Variance_256.3  \
# 0                                           0.003884
# 1                                           0.003875
# 2                                           0.003833
# 3                                           0.003876
# 4                                           0.003847
# 5                                           0.003889
# 6                                           0.003871
# 7                                           0.003873
# 8                                           0.003873
# 9                                           0.003862
# 10                                          0.003833
# 11                                          0.003872
# 12                                          0.003844
# 13                                          0.003827
# 14                                          0.003836
# 15                                          0.003794
# 16                                          0.003872
# 17                                          0.003873
# 18                                          0.003831
# 19                                          0.003875
# 20                                          0.003865
# 21                                          0.003873
# 22                                          0.003865
# 23                                          0.003866
# 24                                          0.003849
# 25                                          0.003879
# 26                                          0.003843
# 27                                          0.003874
# 28                                          0.003843
# 29                                          0.003809
#
#     Texture_Cytoplasm_Mito_Entropy_256.3  \
# 0                               0.020423
# 1                               0.041915
# 2                               0.141666
# 3                               0.041724
# 4                               0.118534
# 5                               0.005824
# 6                               0.055359
# 7                               0.043535
# 8                               0.047104
# 9                               0.074484
# 10                              0.150291
# 11                              0.052307
# 12                              0.119123
# 13                              0.169631
# 14                              0.147470
# 15                              0.250969
# 16                              0.047930
# 17                              0.050589
# 18                              0.156543
# 19                              0.040650
# 20                              0.071253
# 21                              0.050780
# 22                              0.062325
# 23                              0.067368
# 24                              0.111279
# 25                              0.033330
# 26                              0.127098
# 27                              0.044374
# 28                              0.125335
# 29                              0.213779
#
#     Texture_Cytoplasm_Mito_Information.Measure.of.Correlation.1_256.3  \
# 0                                           -0.413421
# 1                                           -0.422158
# 2                                           -0.530708
# 3                                           -0.369338
# 4                                           -0.394003
# 5                                           -0.254247
# 6                                           -0.409934
# 7                                           -0.437722
# 8                                           -0.284079
# 9                                           -0.423008
# 10                                          -0.450034
# 11                                          -0.341628
# 12                                          -0.399782
# 13                                          -0.440251
# 14                                          -0.456886
# 15                                          -0.420643
# 16                                          -0.321390
# 17                                          -0.387890
# 18                                          -0.469787
# 19                                          -0.383870
# 20                                          -0.382977
# 21                                          -0.371964
# 22                                          -0.347031
# 23                                          -0.432205
# 24                                          -0.394978
# 25                                          -0.362958
# 26                                          -0.418609
# 27                                          -0.359799
# 28                                          -0.424372
# 29                                          -0.450506
#
#     Texture_Cytoplasm_Mito_Information.Measure.of.Correlation.2_256.3  \
# 0                                            0.102524
# 1                                            0.148441
# 2                                            0.309519
# 3                                            0.135441
# 4                                            0.235301
# 5                                            0.039860
# 6                                            0.166420
# 7                                            0.153119
# 8                                            0.119175
# 9                                            0.195178
# 10                                           0.286189
# 11                                           0.143739
# 12                                           0.237700
# 13                                           0.298573
# 14                                           0.286737
# 15                                           0.349124
# 16                                           0.131287
# 17                                           0.153384
# 18                                           0.300852
# 19                                           0.136400
# 20                                           0.179997
# 21                                           0.149307
# 22                                           0.155966
# 23                                           0.189603
# 24                                           0.228312
# 25                                           0.119921
# 26                                           0.253050
# 27                                           0.136581
# 28                                           0.252252
# 29                                           0.338998
#
#     Texture_Cytoplasm_Mito_Inverse.Difference.Moment_256.3  \
# 0                                            0.999158
# 1                                            0.998147
# 2                                            0.993609
# 3                                            0.998180
# 4                                            0.994618
# 5                                            0.999758
# 6                                            0.997552
# 7                                            0.998041
# 8                                            0.997755
# 9                                            0.996561
# 10                                           0.993060
# 11                                           0.997611
# 12                                           0.994368
# 13                                           0.992186
# 14                                           0.993288
# 15                                           0.988087
# 16                                           0.997700
# 17                                           0.997765
# 18                                           0.992793
# 19                                           0.998133
# 20                                           0.996764
# 21                                           0.997732
# 22                                           0.996931
# 23                                           0.996982
# 24                                           0.994875
# 25                                           0.998517
# 26                                           0.994143
# 27                                           0.997934
# 28                                           0.994213
# 29                                           0.989992
#
#     Texture_Cytoplasm_Mito_Sum.Average_256.3  \
# 0                                   0.121734
# 1                                   0.088743
# 2                                   0.251323
# 3                                   0.271283
# 4                                   0.974490
# 5                                   0.032513
# 6                                   0.324096
# 7                                   0.032729
# 8                                   0.278011
# 9                                   0.223940
# 10                                  0.751089
# 11                                  0.340906
# 12                                  0.651023
# 13                                  1.057368
# 14                                  1.130372
# 15                                  1.752411
# 16                                  0.159642
# 17                                  0.425465
# 18                                  0.785632
# 19                                  0.142320
# 20                                  0.687328
# 21                                  0.496854
# 22                                  0.130832
# 23                                  0.568430
# 24                                  0.627477
# 25                                  0.288277
# 26                                  0.949956
# 27                                  0.155383
# 28                                  0.614232
# 29                                  1.116895
#
#     Texture_Cytoplasm_Mito_Sum.Entropy_256.3  \
# 0                                   0.017205
# 1                                   0.035999
# 2                                   0.120947
# 3                                   0.035434
# 4                                   0.098255
# 5                                   0.005351
# 6                                   0.046892
# 7                                   0.038891
# 8                                   0.041257
# 9                                   0.064134
# 10                                  0.123984
# 11                                  0.044781
# 12                                  0.099865
# 13                                  0.137966
# 14                                  0.120193
# 15                                  0.202647
# 16                                  0.042096
# 17                                  0.043320
# 18                                  0.128319
# 19                                  0.035592
# 20                                  0.060676
# 21                                  0.043740
# 22                                  0.054522
# 23                                  0.056666
# 24                                  0.092391
# 25                                  0.029173
# 26                                  0.105121
# 27                                  0.038845
# 28                                  0.103510
# 29                                  0.172005
#
#     Texture_Cytoplasm_Mito_Sum.Variance_256.3  \
# 0                                   23.915774
# 1                                    5.313621
# 2                                    9.124662
# 3                                   49.103827
# 4                                  204.130495
# 5                                    6.175817
# 6                                   51.820071
# 7                                    0.914186
# 8                                   40.235163
# 9                                   15.508634
# 10                                  94.651203
# 11                                  56.760924
# 12                                  82.061372
# 13                                 172.162477
# 14                                 219.182061
# 15                                 306.886586
# 16                                  13.497561
# 17                                  90.954372
# 18                                 109.716507
# 19                                  11.681703
# 20                                 160.172720
# 21                                 120.136703
# 22                                   6.264928
# 23                                 113.110757
# 24                                  91.792828
# 25                                  60.895852
# 26                                 168.891792
# 27                                  12.982888
# 28                                  85.038088
# 29                                 156.244215
#
#     Texture_Cytoplasm_Mito_Variance_256.3
# 0                                6.923885
# 1                                1.577140
# 2                                2.542987
# 3                               15.135150
# 4                               60.071187
# 5                                2.162641
# 6                               15.246906
# 7                                0.287058
# 8                               13.623226
# 9                                4.735271
# 10                              27.355627
# 11                              17.453035
# 12                              23.830676
# 13                              48.745423
# 14                              63.350401
# 15                              87.918390
# 16                               4.315735
# 17                              27.668010
# 18                              31.239597
# 19                               3.670517
# 20                              47.336614
# 21                              36.750084
# 22                               1.986908
# 23                              32.155313
# 24                              26.950011
# 25                              18.899241
# 26                              48.572852
# 27                               4.058057
# 28                              24.991360
# 29                              43.282023
#
# [30 rows x 1358 columns]
