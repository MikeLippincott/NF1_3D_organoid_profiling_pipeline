# %% [markdown]
# # Perform organoid-level quality control

# %%
import os
import pathlib
import sys

import pandas as pd
from arg_parsing_utils import parse_args
from cosmicqc import find_outliers
from notebook_init_utils import bandicoot_check, init_notebook

root_dir, in_notebook = init_notebook()

profile_base_dir = bandicoot_check(
    pathlib.Path(os.path.expanduser("~/mnt/bandicoot/NF1_organoid_data")).resolve(),
    root_dir,
)

# %%
if not in_notebook:
    args = parse_args()
    image_based_profiles_subparent_name = args["image_based_profiles_subparent_name"]

else:
    image_based_profiles_subparent_name = "image_based_profiles"

# %% [markdown]
# ## Load in all the organoid profiles and concat together

# %%
# Path to patient folders
path_to_patients = pathlib.Path(f"{profile_base_dir}/data/")

# Get all organoid profiles per patient folder and concatenate them
dfs = []
for patient_folder in path_to_patients.iterdir():
    organoid_file = pathlib.Path(
        patient_folder
        / f"{image_based_profiles_subparent_name}"
        / "2.annotated_profiles/organoid_anno.parquet"
    )
    if organoid_file.exists():
        print(f"Processing {organoid_file}")
        df = pd.read_parquet(organoid_file)
        dfs.append(df)
    else:
        print(f"Organoid profiles file not found for patient folder: {patient_folder}")
orig_organoid_profiles_df = pd.concat(dfs, ignore_index=True)

# Print the shape and head of the combined organoid profiles DataFrame
print(orig_organoid_profiles_df.shape)
orig_organoid_profiles_df.head()
# Out:
# Processing /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0014_T2/image_based_profiles/2.annotated_profiles/organoid_anno.parquet
# Organoid profiles file not found for patient folder: /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0040_T1
# Processing /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0030_T1/image_based_profiles/2.annotated_profiles/organoid_anno.parquet
# Organoid profiles file not found for patient folder: /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0037_T1-Z-1
# Organoid profiles file not found for patient folder: /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/.DS_Store
# Organoid profiles file not found for patient folder: /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/patient_IDs.txt
# Organoid profiles file not found for patient folder: /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/blocklist
# Organoid profiles file not found for patient folder: /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0037_T1-Z-0.1
# Organoid profiles file not found for patient folder: /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/SARCO361_T1
# Organoid profiles file not found for patient folder: /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0037_T1
# Processing /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0016_T1/image_based_profiles/2.annotated_profiles/organoid_anno.parquet
# Processing /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0018_T6/image_based_profiles/2.annotated_profiles/organoid_anno.parquet
# Organoid profiles file not found for patient folder: /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0037_T1-Z-0.2
# Organoid profiles file not found for patient folder: /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0037_T1-Z-0.5
# Processing /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0021_T1/image_based_profiles/2.annotated_profiles/organoid_anno.parquet
# Organoid profiles file not found for patient folder: /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0035_T1
# Organoid profiles file not found for patient folder: /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0037_T1_CQ1
# Organoid profiles file not found for patient folder: /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/all_patient_profiles
# Processing /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0014_T1/image_based_profiles/2.annotated_profiles/organoid_anno.parquet
# Organoid profiles file not found for patient folder: /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/SARCO219_T2
# (4133, 2001)
#   Metadata_patient_tumor  Metadata_object_id Metadata_unit  Metadata_dose  \
# 0              NF0014_T2                  14            nM           10.0
# 1              NF0014_T2                  18            nM           10.0
# 2              NF0014_T2                  10            uM            1.0
# 3              NF0014_T2                  14            uM            1.0
# 4              NF0014_T2                  26            uM            1.0
#
#   Metadata_treatment Metadata_image_set Metadata_Well  \
# 0      Staurosporine              C11-4           C11
# 1      Staurosporine              C11-4           C11
# 2        Selumetinib              D11-5           D11
# 3        Selumetinib              D11-5           D11
# 4        Selumetinib              D11-5           D11
#
#    Metadata_single_cell_count  Area.Size.Shape_Organoid_VOLUME  \
# 0                         NaN                        1296580.0
# 1                         NaN                            128.0
# 2                         NaN                        2832086.0
# 3                         NaN                            288.0
# 4                         NaN                           1772.0
#
#    Area.Size.Shape_Organoid_CENTER.X  ...  \
# 0                         824.287109  ...
# 1                         604.625000  ...
# 2                         760.868103  ...
# 3                         842.194458  ...
# 4                        1003.268616  ...
#
#    Texture_Organoid_Mito_Sum.Average_256.3  \
# 0                                 2.163053
# 1                                 0.000727
# 2                                 2.067724
# 3                                 0.001829
# 4                                 0.008353
#
#    Texture_Organoid_Mito_Sum.Entropy_256.3  \
# 0                                 0.278313
# 1                                 0.000082
# 2                                 0.734140
# 3                                 0.000232
# 4                                 0.000920
#
#    Texture_Organoid_Mito_Sum.Variance_256.3  \
# 0                                228.354152
# 1                                  0.145701
# 2                                 92.356472
# 3                                  0.316325
# 4                                  1.516083
#
#    Texture_Organoid_Mito_Variance_256.3      Metadata_Target  Metadata_Class  \
# 0                             70.320466  Apoptosis induction  Small Molecule
# 1                              0.071439  Apoptosis induction  Small Molecule
# 2                             27.130117     MEK1/2 inhibitor  Small Molecule
# 3                              0.146497     MEK1/2 inhibitor  Small Molecule
# 4                              0.676050     MEK1/2 inhibitor  Small Molecule
#
#    Metadata_Therapeutic_Categories  Metadata_patient  Metadata_tumor  \
# 0                     Experimental            NF0014              T2
# 1                     Experimental            NF0014              T2
# 2                 Kinase Inhibitor            NF0014              T2
# 3                 Kinase Inhibitor            NF0014              T2
# 4                 Kinase Inhibitor            NF0014              T2
#
#    Metadata_patient_id
# 0            NF0014_T2
# 1            NF0014_T2
# 2            NF0014_T2
# 3            NF0014_T2
# 4            NF0014_T2
#
# [5 rows x 2001 columns]

# %% [markdown]
# ## Perform a first round of QC by flagging any row with NaNs in metadata
#
# We check for NaNs in the `object_id` and/or the `single_cell_count` column and flag them because:
#    - An organoid can not exist if there aren't any cells.
#    - NaN in object_id would be incorrect as that means the object/organoid does not exist (will have all NaNs in the feature space).

# %%
organoid_profiles_df = orig_organoid_profiles_df.copy()
organoid_profiles_df["Metadata_cqc_nan_detected"] = (
    organoid_profiles_df[
        [
            "Metadata_object_id",
            "Metadata_single_cell_count",
            "Area.Size.Shape_Organoid_VOLUME",
        ]
    ]
    .isna()
    .any(axis=1)
)
# Print the number of organoids flagged
flagged_count = organoid_profiles_df["Metadata_cqc_nan_detected"].sum()
print(f"Number of organoids flagged: {flagged_count}")

organoid_profiles_df.head()
# Out:
# Number of organoids flagged: 3453
#   Metadata_patient_tumor  Metadata_object_id Metadata_unit  Metadata_dose  \
# 0              NF0014_T2                  14            nM           10.0
# 1              NF0014_T2                  18            nM           10.0
# 2              NF0014_T2                  10            uM            1.0
# 3              NF0014_T2                  14            uM            1.0
# 4              NF0014_T2                  26            uM            1.0
#
#   Metadata_treatment Metadata_image_set Metadata_Well  \
# 0      Staurosporine              C11-4           C11
# 1      Staurosporine              C11-4           C11
# 2        Selumetinib              D11-5           D11
# 3        Selumetinib              D11-5           D11
# 4        Selumetinib              D11-5           D11
#
#    Metadata_single_cell_count  Area.Size.Shape_Organoid_VOLUME  \
# 0                         NaN                        1296580.0
# 1                         NaN                            128.0
# 2                         NaN                        2832086.0
# 3                         NaN                            288.0
# 4                         NaN                           1772.0
#
#    Area.Size.Shape_Organoid_CENTER.X  ...  \
# 0                         824.287109  ...
# 1                         604.625000  ...
# 2                         760.868103  ...
# 3                         842.194458  ...
# 4                        1003.268616  ...
#
#    Texture_Organoid_Mito_Sum.Entropy_256.3  \
# 0                                 0.278313
# 1                                 0.000082
# 2                                 0.734140
# 3                                 0.000232
# 4                                 0.000920
#
#    Texture_Organoid_Mito_Sum.Variance_256.3  \
# 0                                228.354152
# 1                                  0.145701
# 2                                 92.356472
# 3                                  0.316325
# 4                                  1.516083
#
#    Texture_Organoid_Mito_Variance_256.3      Metadata_Target  Metadata_Class  \
# 0                             70.320466  Apoptosis induction  Small Molecule
# 1                              0.071439  Apoptosis induction  Small Molecule
# 2                             27.130117     MEK1/2 inhibitor  Small Molecule
# 3                              0.146497     MEK1/2 inhibitor  Small Molecule
# 4                              0.676050     MEK1/2 inhibitor  Small Molecule
#
#    Metadata_Therapeutic_Categories  Metadata_patient  Metadata_tumor  \
# 0                     Experimental            NF0014              T2
# 1                     Experimental            NF0014              T2
# 2                 Kinase Inhibitor            NF0014              T2
# 3                 Kinase Inhibitor            NF0014              T2
# 4                 Kinase Inhibitor            NF0014              T2
#
#    Metadata_patient_id  cqc.nan_detected
# 0            NF0014_T2              True
# 1            NF0014_T2              True
# 2            NF0014_T2              True
# 3            NF0014_T2              True
# 4            NF0014_T2              True
#
# [5 rows x 2002 columns]

# %% [markdown]
# ## Process non-NaN rows to detect abnormally small and large organoids and flag them

# %%
# Set the metadata columns to be used in the QC process
metadata_columns = [
    "Metadata_patient_tumor",
    "Metadata_image_set",
    "Metadata_single_cell_count",
    "Metadata_object_id",
    "Metadata_cqc_nan_detected",
]

# %%
# Process each plate (patient_id) independently in the combined dataframe
for plate_name, plate_df in organoid_profiles_df.groupby("Metadata_patient_tumor"):
    print(f"Processing plate: {plate_name}")

    # Only process the rows that are not flagged
    filtered_plate_df = plate_df[~plate_df["Metadata_cqc_nan_detected"]]

    # Find outlier organoids based on the 'Area.Size.Shape_Organoid_VOLUME' column
    print("Finding small organoid outliers...")
    small_size_outliers = find_outliers(
        df=filtered_plate_df,
        metadata_columns=metadata_columns,
        feature_thresholds={
            "Area.Size.Shape_Organoid_VOLUME": -1,  # Detect very small organoids
        },
    )

    # Ensure the column exists before assignment
    plate_df["Metadata_cqc_small_organoid_outlier"] = False
    plate_df.loc[small_size_outliers.index, "Metadata_cqc_small_organoid_outlier"] = (
        True
    )

    print("Finding large organoid outliers...")
    large_size_outliers = find_outliers(
        df=filtered_plate_df,
        metadata_columns=metadata_columns,
        feature_thresholds={
            "Area.Size.Shape_Organoid_VOLUME": 3,  # Detect very large organoids
        },
    )

    # Ensure the column exists before assignment
    plate_df["Metadata_cqc_large_organoid_outlier"] = False
    plate_df.loc[large_size_outliers.index, "Metadata_cqc_large_organoid_outlier"] = (
        True
    )

    # Update original dataframe so flags persist
    organoid_profiles_df.loc[plate_df.index, :] = plate_df

    # Print number of outliers (only in filtered rows)
    small_count = filtered_plate_df.index.intersection(small_size_outliers.index).shape[
        0
    ]
    large_count = filtered_plate_df.index.intersection(large_size_outliers.index).shape[
        0
    ]
    print(f"Small organoid outliers found: {small_count}")
    print(f"Large organoid outliers found: {large_count}")

    # Save updated plate_df with flag columns included
    output_folder = path_to_patients / plate_name / "image_based_profiles/3.qc_profiles"
    output_folder.mkdir(parents=True, exist_ok=True)
    output_file = output_folder / "organoid_flagged_outliers.parquet"
    plate_df.to_parquet(output_file, index=False)
    print(f"Saved organoid profiles with outlier flags to {output_file}\n")
# Out:
# Processing plate: NF0014_T1
# Finding small organoid outliers...
# Number of outliers: 12 (15.19%)
# Outliers Range:
# Area.Size.Shape_Organoid_VOLUME Min: 460122.0
# Area.Size.Shape_Organoid_VOLUME Max: 2018826.0
# Finding large organoid outliers...
# Number of outliers: 1 (1.27%)
# Outliers Range:
# Area.Size.Shape_Organoid_VOLUME Min: 28609348.0
# Area.Size.Shape_Organoid_VOLUME Max: 28609348.0
# Small organoid outliers found: 12
# Large organoid outliers found: 1
# Saved organoid profiles with outlier flags to /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0014_T1/image_based_profiles/1a.qc_profiles/organoid_flagged_outliers.parquet
#
# Processing plate: NF0014_T2
# Finding small organoid outliers...
# Number of outliers: 14 (10.45%)
# Outliers Range:
# Area.Size.Shape_Organoid_VOLUME Min: 138328.0
# Area.Size.Shape_Organoid_VOLUME Max: 576308.0
# Finding large organoid outliers...
# Number of outliers: 4 (2.99%)
# Outliers Range:
# Area.Size.Shape_Organoid_VOLUME Min: 8160154.0
# Area.Size.Shape_Organoid_VOLUME Max: 9560601.0
# Small organoid outliers found: 14
# Large organoid outliers found: 4
# Saved organoid profiles with outlier flags to /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0014_T2/image_based_profiles/1a.qc_profiles/organoid_flagged_outliers.parquet
#
# Processing plate: NF0016_T1
# Finding small organoid outliers...
# Number of outliers: 4 (5.63%)
# Outliers Range:
# Area.Size.Shape_Organoid_VOLUME Min: 2332.0
# Area.Size.Shape_Organoid_VOLUME Max: 309360.0
# Finding large organoid outliers...
# Number of outliers: 1 (1.41%)
# Outliers Range:
# Area.Size.Shape_Organoid_VOLUME Min: 19496176.0
# Area.Size.Shape_Organoid_VOLUME Max: 19496176.0
# Small organoid outliers found: 4
# Large organoid outliers found: 1
# Saved organoid profiles with outlier flags to /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0016_T1/image_based_profiles/1a.qc_profiles/organoid_flagged_outliers.parquet
#
# Processing plate: NF0018_T6
# Finding small organoid outliers...
# Number of outliers: 4 (4.88%)
# Outliers Range:
# Area.Size.Shape_Organoid_VOLUME Min: 8529.0
# Area.Size.Shape_Organoid_VOLUME Max: 366166.0
# Finding large organoid outliers...
# Number of outliers: 1 (1.22%)
# Outliers Range:
# Area.Size.Shape_Organoid_VOLUME Min: 14915400.0
# Area.Size.Shape_Organoid_VOLUME Max: 14915400.0
# Small organoid outliers found: 4
# Large organoid outliers found: 1
# Saved organoid profiles with outlier flags to /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0018_T6/image_based_profiles/1a.qc_profiles/organoid_flagged_outliers.parquet
#
# Processing plate: NF0021_T1
# Finding small organoid outliers...
# Number of outliers: 7 (3.04%)
# Outliers Range:
# Area.Size.Shape_Organoid_VOLUME Min: 119744.0
# Area.Size.Shape_Organoid_VOLUME Max: 216209.0
# Finding large organoid outliers...
# Number of outliers: 5 (2.17%)
# Outliers Range:
# Area.Size.Shape_Organoid_VOLUME Min: 13724706.0
# Area.Size.Shape_Organoid_VOLUME Max: 20708756.0
# Small organoid outliers found: 7
# Large organoid outliers found: 5
# Saved organoid profiles with outlier flags to /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0021_T1/image_based_profiles/1a.qc_profiles/organoid_flagged_outliers.parquet
#
# Processing plate: NF0030_T1
# Finding small organoid outliers...
# Number of outliers: 0 (0.00%)
# Outliers Range:
# Area.Size.Shape_Organoid_VOLUME Min: nan
# Area.Size.Shape_Organoid_VOLUME Max: nan
# Finding large organoid outliers...
# Number of outliers: 2 (2.38%)
# Outliers Range:
# Area.Size.Shape_Organoid_VOLUME Min: 21443088.0
# Area.Size.Shape_Organoid_VOLUME Max: 37991080.0
# Small organoid outliers found: 0
# Large organoid outliers found: 2
# Saved organoid profiles with outlier flags to /home/lippincm/mnt/bandicoot/NF1_organoid_data/data/NF0030_T1/image_based_profiles/1a.qc_profiles/organoid_flagged_outliers.parquet

# %%
# Print example output of the flagged organoid profiles
print(f"Example flagged organoid profiles: {plate_name}")
print(plate_df.shape)
plate_df.head()
# Out:
# Example flagged organoid profiles: NF0030_T1
# (396, 2004)
#      Metadata_patient_tumor  Metadata_object_id Metadata_unit  Metadata_dose  \
# 1432              NF0030_T1                   4            nM           10.0
# 1433              NF0030_T1                   8            nM           10.0
# 1434              NF0030_T1                  12            nM           10.0
# 1435              NF0030_T1                  30            nM           10.0
# 1436              NF0030_T1                  33            nM           10.0
#
#      Metadata_treatment Metadata_image_set Metadata_Well  \
# 1432      Staurosporine              C11-4           C11
# 1433      Staurosporine              C11-4           C11
# 1434      Staurosporine              C11-4           C11
# 1435      Staurosporine              C11-4           C11
# 1436      Staurosporine              C11-4           C11
#
#       Metadata_single_cell_count  Area.Size.Shape_Organoid_VOLUME  \
# 1432                         NaN                        2632089.0
# 1433                         NaN                            372.0
# 1434                         NaN                        1510316.0
# 1435                         NaN                        2938900.0
# 1436                         NaN                         142092.0
#
#       Area.Size.Shape_Organoid_CENTER.X  ...  \
# 1432                         882.465332  ...
# 1433                         315.010742  ...
# 1434                         264.324921  ...
# 1435                         713.619446  ...
# 1436                         804.719055  ...
#
#       Texture_Organoid_Mito_Variance_256.3      Metadata_Target  \
# 1432                             48.541913  Apoptosis induction
# 1433                              0.120026  Apoptosis induction
# 1434                             43.012409  Apoptosis induction
# 1435                            107.057396  Apoptosis induction
# 1436                             19.405408  Apoptosis induction
#
#       Metadata_Class  Metadata_Therapeutic_Categories  Metadata_patient  \
# 1432  Small Molecule                     Experimental            NF0030
# 1433  Small Molecule                     Experimental            NF0030
# 1434  Small Molecule                     Experimental            NF0030
# 1435  Small Molecule                     Experimental            NF0030
# 1436  Small Molecule                     Experimental            NF0030
#
#       Metadata_tumor  Metadata_patient_id  cqc.nan_detected  \
# 1432              T1            NF0030_T1              True
# 1433              T1            NF0030_T1              True
# 1434              T1            NF0030_T1              True
# 1435              T1            NF0030_T1              True
# 1436              T1            NF0030_T1              True
#
#       cqc.small_organoid_outlier  cqc.large_organoid_outlier
# 1432                       False                       False
# 1433                       False                       False
# 1434                       False                       False
# 1435                       False                       False
# 1436                       False                       False
#
# [5 rows x 2004 columns]
